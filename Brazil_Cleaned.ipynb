# %%
#open csv file. Upload BraziLGrainCongestion_date into the directory. This code checks that the correct file has been uploaded.  
import csv

#changefilename
file = open ("SOYA COMPLEX + CORN - 25.01.2022.csv")
csv_file = csv.reader (file)

# %%
for row in csv_file:
    print('{:<20} {:<15} {:<15} {:<15} {:<10} {:<15} {:<25} '.format(*row))
# Out:
# ï»¿                  Williams Brazil
#                      SOYAÂ COMPLEXÂ + CORN VESSELS LINE-UP
#                      Edition 25.01.2022
#                      Â© 2022 Williams Servicos Maritimos Ltda, Brazil
#                      142 YEARS SERVING THE BRAZILIANÂ  FOREIGN COMMERCE TRANSPORTATION INDUSTRY
#
#                      PERIOD 01.01.2022 - 25.01.2022
#
# ITACOATIARA PORT - AM
# VESSEL               STATUS          ETA             ETB             ETS         LOADED         CARGO
# VESSELS TO LOAD GRAINS AT HERMASA I TERMINAL
# AKRA                 SAILED          15.12           28.12           06.01       28,350.000     HIPRO
#                                                                                  21,000.000     PELLETS
# WL KIRILLOV          SAILED          06.01           07.01           09.01       30,250.000     SOYABEAN
# IRIS EXPRESS         SAILED          13.01           14.01           17.01       44,000.000     CORN
# ...

# %%
#Pythonic Data Cleaning

#create dataframe from the CSV file. 

import pandas as pd
import numpy as np

#changefilename
df= pd.read_csv("SOYA COMPLEX + CORN - 25.01.2022.csv")

#deletes row headers
df.drop(index=df.index[:7], axis=0, inplace=True)


#renames columns
df = df.rename(columns = {'Unnamed: 0':'Vessels','Williams Brazil':'Status','Unnamed: 2':'ETA','Unnamed: 3':'ETB', 'Unnamed: 4':'ETS', 'Unnamed: 5':'Loaded','Unnamed: 6':'Cargo', 'Unnamed: 7':'Destination', 'Unnamed: 8':'Terminal','Unnamed: 9':'Buyers'})
empty_cols = [col for col in df.columns if df[col].isnull().all()]

# Drop empty columns from the dataframe
df.drop(empty_cols,
        axis=1,
        inplace=True)

#drop terminals

#df = pd.read_csv('BrazilGrainCongestion_7Dec.csv',index_col= 'Ports and Vessels')
#df.drop (['VESSELS TO LOAD GRAINS AT HERMASA I TERMINAL'], inplace = "True") 

df= df[df['Vessels'] != 'VESSELS TO LOAD GRAINS AT HERMASA I TERMINAL']
df= df[df['Vessels'] != 'VESSELS TO LOAD GRAINS AT HERMASA II TERMINAL']
df= df[df['Vessels'] != 'VESSELS TO LOAD GRAINS AT CIANPORT']
df= df[df['Vessels'] != 'VESSELS TO LOAD GRAINS AT CARGILL TERMINAL']
df= df[df['Vessels'] != 'VESSELS TO LOAD GRAINS AT CDP 101']
df= df[df['Vessels'] != 'VESSELS TO LOAD GRAINS AT CDP 201']
df= df[df['Vessels'] != 'VESSELS TO LOAD GRAINS AT COMMERCIAL BERTH']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT  UNITAPAJOS (EX-TERFRON) TERMINAL']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT TGPM - ADM/ GLENCORE TERMINAL']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT HIDROVIAS TERMINAL']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT OUTEIRO CDP 301']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT MEGA TERMINAL']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT BERTH 100']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT BERTH 103 - TEGRAM']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT BERTH 105 - VALE TERMINAL']
df= df[df['Vessels'] != 'VESSELS TO LOAD GRAINS AT COTEGIPE TERMINAL']
df= df[df['Vessels'] != 'VESSELS TO LOAD GRAINS AT COMMERCIAL BERTH']
df= df[df['Vessels'] != 'VESSELS TO LOAD GRAINS AT TPD3']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT TES - SHED 38 - EXPORT CORRIDOR']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT BERTH 37']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT ADM TERMINAL / SHED 39']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT TEG']
df= df[df['Vessels'] != '         VESSEL TO LOAD GRAINS AT TEAG']
df= df[df['Vessels'] != '         VESSEL TO LOAD GRAINS AT TGG']
df= df[df['Vessels'] != '         VESSEL TO LOAD GRAINS AT CUTRALE TERMINAL']
df= df[df['Vessels'] != '         VESSEL TO LOAD GRAINS AT T-GRAO / SHED 26']
df= df[df['Vessels'] != '         VESSEL TO LOAD GRAINS AT COPERSUCAR TERMINAL']
df= df[df['Vessels'] != '         VESSEL TO LOAD GRAINS AT RUMO TERMINAL / SHED 16/17 ']
df= df[df['Vessels'] != '         VESSEL TO LOAD GRAINS AT RUMO TERMINAL / SHED 19 ']
df= df[df['Vessels'] != '         VESSEL TO LOAD GRAINS AT COFCO TERMINAL / SHED T12A']
df= df[df['Vessels'] != '         VESSEL TO LOAD GRAINS AT TIPLAM 2']
df= df[df['Vessels'] != '         VESSEL TO LOAD GRAINS AT TIPLAM 3']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT WEST CORRIDOR - SHED 201']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT PASA TERMINAL - SHED 204']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT BUNGE TERMINAL - SHED 206']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT SHED 212 TERMINAL - EXPORT CORRIDOR ']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT SHED 213 TERMINAL - EXPORT CORRIDOR ']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT SHED 214 TERMINAL - EXPORT CORRIDOR ']
df= df[df['Vessels'] != 'PONTA DO FELIX TERMINAL / ANTONINA SHED 01']
df= df[df['Vessels'] != 'PONTA DO FELIX TERMINAL / ANTONINA SHED 02']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT PIER 01']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT PIER 02']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT PIER 03']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT TERMASA TERMINAL ']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT TERGRASA TERMINAL']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT BUNGE TERMINAL ']
df= df[df['Vessels'] != 'VESSEL TO LOAD GRAINS AT BIANCHINI']

df.head(20)
# Out:
#                   Vessels     Status    ETA    ETB    ETS        Loaded  \
# 7   ITACOATIARA PORT - AM        NaN    NaN    NaN    NaN           NaN
# 8                  VESSEL     STATUS    ETA    ETB    ETS       LOADED
# 10                   AKRA     SAILED  15.12  28.12  06.01   28,350.000
# 11                    NaN        NaN    NaN    NaN    NaN   21,000.000
# 12            WL KIRILLOV     SAILED  06.01  07.01  09.01   30,250.000
# 13           IRIS EXPRESS     SAILED  13.01  14.01  17.01   44,000.000
# 14                ICARIUS     SAILED  18.01  18.01  21.01   46,760.000
# 15            UBC TILBURY     SAILED  21.01  21.01  24.01   31,697.000
# 16                    NaN        NaN    NaN    NaN    NaN   18,323.000
# 17          AOM SOPHIE II    LOADING  20.01  25.01  28.01   55,669.000
# 18      RIDGEBURY MERCURY  AT ANCHOR  24.01  28.01  30.01   18,900.000
# 19            OCEAN THYME  AT ANCHOR  17.01  31.01  07.02   30,800.000
# ...

# %%
#export excel file as csv into specified pathway

#wait for code to execute above


df.to_csv(r'C:\Users\ree\Desktop\Congestion\BrazilGrainCongestionTODAY.csv',index=False)
